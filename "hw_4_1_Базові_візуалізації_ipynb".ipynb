#        -3.80904523e+01, -3.75376884e+01, -3.69849246e+01, -3.64321608e+01,
#        -3.58793970e+01, -3.53266332e+01, -3.47738693e+01, -3.42211055e+01,
#        -3.36683417e+01, -3.31155779e+01, -3.25628141e+01, -3.20100503e+01,
#        -3.14572864e+01, -3.09045226e+01, -3.03517588e+01, -2.97989950e+01,
#        -2.92462312e+01, -2.86934673e+01, -2.81407035e+01, -2.75879397e+01,
#        -2.70351759e+01, -2.64824121e+01, -2.59296482e+01, -2.53768844e+01,
#        -2.48241206e+01, -2.42713568e+01, -2.37185930e+01, -2.31658291e+01,
#        -2.26130653e+01, -2.20603015e+01, -2.15075377e+01, -2.09547739e+01,
#        -2.04020101e+01, -1.98492462e+01, -1.92964824e+01, -1.87437186e+01,
#        -1.81909548e+01, -1.76381910e+01, -1.70854271e+01, -1.65326633e+01,
#        -1.59798995e+01, -1.54271357e+01, -1.48743719e+01, -1.43216080e+01,
#        -1.37688442e+01, -1.32160804e+01, -1.26633166e+01, -1.21105528e+01,
#        -1.15577889e+01, -1.10050251e+01, -1.04522613e+01, -9.89949749e+00,
#        -9.34673367e+00, -8.79396985e+00, -8.24120603e+00, -7.68844221e+00,
#        -7.13567839e+00, -6.58291457e+00, -6.03015075e+00, -5.47738693e+00,
#        -4.92462312e+00, -4.37185930e+00, -3.81909548e+00, -3.26633166e+00,
#        -2.71356784e+00, -2.16080402e+00, -1.60804020e+00, -1.05527638e+00,
#        -5.02512563e-01,  5.02512563e-02,  6.03015075e-01,  1.15577889e+00,
#         1.70854271e+00,  2.26130653e+00,  2.81407035e+00,  3.36683417e+00,
#         3.91959799e+00,  4.47236181e+00,  5.02512563e+00,  5.57788945e+00,
#         6.13065327e+00,  6.68341709e+00,  7.23618090e+00,  7.78894472e+00,
#         8.34170854e+00,  8.89447236e+00,  9.44723618e+00,  1.00000000e+01])

# %% [markdown]
# 2. Створіть змінну `y_linear`, яка буде містити результат обчислення лінійної функції `y = 2x + 1`. Враховуйте, що змінну `x` ми створили з `numpy`, а значить для арифметичних обчислень з нею нам не треба цикл, бо можемо працювати з цыэю змінною, як з вектором (так само, як працюємо з колонками в `pandas`)

# %%
y_linear = 2*x + 1

# %% [markdown]
# 3. Створіть змінну, яка буде містити результат обчислення квадратичної функції `y = x^2 - x - 2`.

# %%
y_quadratic = x**2 - x - 2

# %% [markdown]
# 4. Побудуйте лінійну візуалізацію значень змінної `y_linear` за відповідних значень `x`.

# %%
plt.plot(y_linear);

# %% [markdown]
# 5. Побудуйте лінійну візуалізацію значень змінної `y_quadratic` за відповідних значень x.

# %%
plt.plot(y_quadratic);

# %% [markdown]
# 6. Побудуйте графіки обох функцій на одному графіку:
#    - Використайте червоний колір та суцільну лінію для лінійної функції.
#    - Використайте зелений колір та переривчасту лінію для квадратичної функції.

# %%
plt.plot(y_linear, color='r', linestyle='-')
plt.plot(y_quadratic, color='g', linestyle='--');

# %% [markdown]
# Виглядає непогано! Але давайте для солідності додамо підписи графіку і на осях, а також сітку і легенду. Про це буде в наступному уроці, а поки просто вставте замість трьох крапок спочатку наповнення (те, що на попередньому кроці було всередині p для побудови графіку лінійної фукнції, потім - квадратичної і запустіть код.

# %%
plt.plot(y_linear, color='r', linestyle='-', label='Лінійна функція')
plt.plot(y_quadratic, color='g', linestyle='--', label='Квадратична функція')
plt.title('Порівняння лінійної та квадратичної функцій')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
